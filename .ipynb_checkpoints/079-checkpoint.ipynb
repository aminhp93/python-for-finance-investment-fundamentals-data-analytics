# %%
import numpy as np
import pandas as pd
import pandas_datareader as wb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
assets = ['PG', '^GSPC']
pf_data = pd.DataFrame()
for a in assets:
    pf_data[a] = wb.DataReader(a, data_source='yahoo', start='2010-1-1')['Adj Close']

# %%
pf_data.tail()
# Out:
#                     PG        ^GSPC
# Date
# 2019-03-15  102.440002  2822.479980
# 2019-03-18  101.510002  2832.939941
# 2019-03-19  101.900002  2832.570068
# 2019-03-20  101.720001  2824.229980
# 2019-03-21  102.709999  2848.510010

# %%
(pf_data / pf_data.iloc[0] * 100).plot(figsize=(10, 5))

# %%
pf_data.iloc[0]
# Out:
# PG         45.145977
# ^GSPC    1115.099976
# Name: 2009-12-31 00:00:00, dtype: float64

# %%
log_returns = np.log(pf_data / pf_data.shift(1))

# %%
log_returns.mean() * 250
# Out:
# PG       0.088617
# ^GSPC    0.101105
# dtype: float64

# %%
log_returns.cov() * 250
# Out:
#              PG     ^GSPC
# PG     0.021236  0.011595
# ^GSPC  0.011595  0.022309

# %%
log_returns.corr()
# Out:
#              PG     ^GSPC
# PG     1.000000  0.532701
# ^GSPC  0.532701  1.000000

# %%
log_returns
# Out:
#                   PG     ^GSPC
# Date
# 2009-12-31       NaN       NaN
# 2010-01-04  0.008049  0.015916
# 2010-01-05  0.000327  0.003111
# 2010-01-06 -0.004755  0.000545
# 2010-01-07 -0.005438  0.003993
# 2010-01-08 -0.001323  0.002878
# 2010-01-11 -0.003979  0.001745
# 2010-01-12  0.011397 -0.009425
# 2010-01-13  0.010293  0.008291
# 2010-01-14  0.000975  0.002423
# 2010-01-15 -0.012418 -0.010882
# 2010-01-19  0.014689  0.012422
# 2010-01-20 -0.013637 -0.010654
# 2010-01-21 -0.010142 -0.019127
# 2010-01-22  0.007824 -0.022390
# 2010-01-25  0.005292  0.004588
# 2010-01-26  0.000989 -0.004212
# 2010-01-27  0.001975  0.004868
# 2010-01-28  0.014206 -0.011888
# 2010-01-29 -0.002110 -0.009878
# 2010-02-01  0.007124  0.014165
# 2010-02-02  0.014573  0.012890
# 2010-02-03 -0.003983 -0.005489
# 2010-02-04 -0.020154 -0.031636
# 2010-02-05 -0.001630  0.002893
# 2010-02-08 -0.004742 -0.008903
# 2010-02-09  0.012218  0.012956
# 2010-02-10 -0.001458 -0.002235
# 2010-02-11  0.004691  0.009634
# 2010-02-12 -0.003233 -0.002748
# ...              ...       ...
# 2019-02-07 -0.007998 -0.009401
# 2019-02-08  0.005851  0.000676
# 2019-02-11  0.005715  0.000709
# 2019-02-12  0.010024  0.012808
# 2019-02-13 -0.000202  0.003019
# 2019-02-14 -0.007891 -0.002655
# 2019-02-15  0.000203  0.010820
# 2019-02-19  0.015217  0.001498
# 2019-02-20 -0.007126  0.001776
# 2019-02-21  0.005024 -0.003533
# 2019-02-22  0.004699  0.006391
# 2019-02-25 -0.006806  0.001231
# 2019-02-26  0.002608 -0.000791
# 2019-02-27 -0.009258 -0.000544
# 2019-02-28 -0.003646 -0.002830
# 2019-03-01 -0.001117  0.006872
# 2019-03-04  0.004359 -0.003888
# 2019-03-05  0.002223 -0.001132
# 2019-03-06 -0.001616 -0.006545
# 2019-03-07 -0.003848 -0.008159
# 2019-03-08 -0.001422 -0.002134
# 2019-03-11  0.011819  0.014560
# 2019-03-12  0.004709  0.002949
# 2019-03-13  0.011231  0.006926
# 2019-03-14  0.001383 -0.000868
# 2019-03-15  0.010993  0.004973
# 2019-03-18 -0.009120  0.003699
# 2019-03-19  0.003835 -0.000131
# 2019-03-20 -0.001768 -0.002949
# 2019-03-21  0.009686  0.008560
#
# [2320 rows x 2 columns]

# %%
num_assets = len(assets)

# %%
num_assets
# Out:
# 2

# %%
arr = np.random.random(2)
arr
# Out:
# array([0.2063563 , 0.28512108])

# %%
arr[0] + arr[1]
# Out:
# 0.49147738137200114

# %%
weights = np.random.random(num_assets)
weights /= np.sum(weights)
weights
# Out:
# array([0.4572166, 0.5427834])

# %%
weights[0] + weights[1]
# Out:
# 1.0
